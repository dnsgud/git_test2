# %% [markdown]
# <a href="https://colab.research.google.com/github/dnsgud/git_test2/blob/master/01%EC%B0%A8%EC%8B%9C_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("테스트")
# Out:
# 테스트

# %%
import requests

# %%
res = requests.get("https://api.covid19api.com/summary")
res.status_code
# res.headers
raw_data = res.json()

# %%
raw_data
# Out:
# {'Countries': [{'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Date': '2020-08-08T00:37:57Z',
#    'NewConfirmed': 67,
#    'NewDeaths': 4,
#    'NewRecovered': 98,
#    'Premium': {},
#    'Slug': 'afghanistan',
#    'TotalConfirmed': 36896,
#    'TotalDeaths': 1298,
#    'TotalRecovered': 25840},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Date': '2020-08-08T00:37:57Z',
#    'NewConfirmed': 127,
#    'NewDeaths': 6,
#    'NewRecovered': 32,
#    'Premium': {},
#    'Slug': 'albania',
#    'TotalConfirmed': 6016,
#    'TotalDeaths': 188,
#    'TotalRecovered': 3155},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Date': '2020-08-08T00:37:57Z',
#    'NewConfirmed': 571,
#    'NewDeaths': 12,
#    'NewRecovered': 436,
#    'Premium': {},
#    'Slug': 'algeria',
#    'TotalConfirmed': 33626,
#    'TotalDeaths': 1273,
#    'TotalRecovered': 23238},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Date': '2020-08-08T00:37:57Z',
# ...

# %%
raw_data["Global"]
# Out:
# {'NewConfirmed': 285196,
#  'NewDeaths': 6516,
#  'NewRecovered': 189126,
#  'TotalConfirmed': 19096415,
#  'TotalDeaths': 714924,
#  'TotalRecovered': 11544750}

# %%
for i in raw_data['Global']:
  print(i)
# Out:
# NewConfirmed
# TotalConfirmed
# NewDeaths
# TotalDeaths
# NewRecovered
# TotalRecovered

# %%
for i in raw_data['Countries']:
  print(i)
# Out:
# {'Country': 'Afghanistan', 'CountryCode': 'AF', 'Slug': 'afghanistan', 'NewConfirmed': 67, 'TotalConfirmed': 36896, 'NewDeaths': 4, 'TotalDeaths': 1298, 'NewRecovered': 98, 'TotalRecovered': 25840, 'Date': '2020-08-08T00:37:57Z', 'Premium': {}}
# {'Country': 'Albania', 'CountryCode': 'AL', 'Slug': 'albania', 'NewConfirmed': 127, 'TotalConfirmed': 6016, 'NewDeaths': 6, 'TotalDeaths': 188, 'NewRecovered': 32, 'TotalRecovered': 3155, 'Date': '2020-08-08T00:37:57Z', 'Premium': {}}
# {'Country': 'Algeria', 'CountryCode': 'DZ', 'Slug': 'algeria', 'NewConfirmed': 571, 'TotalConfirmed': 33626, 'NewDeaths': 12, 'TotalDeaths': 1273, 'NewRecovered': 436, 'TotalRecovered': 23238, 'Date': '2020-08-08T00:37:57Z', 'Premium': {}}
# {'Country': 'Andorra', 'CountryCode': 'AD', 'Slug': 'andorra', 'NewConfirmed': 5, 'TotalConfirmed': 944, 'NewDeaths': 0, 'TotalDeaths': 52, 'NewRecovered': 3, 'TotalRecovered': 828, 'Date': '2020-08-08T00:37:57Z', 'Premium': {}}
# ...

# %%
import csv
with open("test.csv","w") as f:
  csv_writer = csv.writer(f)
  d = raw_data()
